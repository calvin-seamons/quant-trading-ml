# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from datetime import datetime
import os
from pathlib import Path
import logging
import yaml
import sys
import requests
import json
import yfinance as yf
from typing import List, Set, Tuple
from concurrent.futures import ThreadPoolExecutor, as_completed
import time

from Backtest import Backtest

# Set up logging with more detailed format
logging.basicConfig(
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    stream=sys.stdout,  # Ensure output goes to notebook
    level=logging.INFO
)
logger = logging.getLogger(__name__)

# Test logger to ensure it prints to the output
logger.info("Logger is set up and ready to capture info statements.")
# Out:
# 2024-12-27 23:19:18,515 - __main__ - INFO - Logger is set up and ready to capture info statements.

# %%
def setup_directories():
    """Create necessary directories for the backtest system."""
    try:
        # Define base directories
        __file__ = os.path.abspath('main.ipynb')
        base_dir = os.path.abspath(os.path.dirname(__file__))
        data_dir = os.path.join(base_dir, 'data')
        db_dir = os.path.join(data_dir, 'db')
        cache_dir = os.path.join(data_dir, 'cache')
        
        logger.debug(f"Setting up directories:")
        logger.debug(f"Base dir: {base_dir}")
        logger.debug(f"Data dir: {data_dir}")
        logger.debug(f"DB dir: {db_dir}")
        logger.debug(f"Cache dir: {cache_dir}")
        
        # Create directories
        Path(data_dir).mkdir(exist_ok=True)
        Path(db_dir).mkdir(exist_ok=True)
        Path(cache_dir).mkdir(exist_ok=True)
        
        # Verify directories were created
        for dir_path in [data_dir, db_dir, cache_dir]:
            if not os.path.exists(dir_path):
                raise RuntimeError(f"Failed to create directory: {dir_path}")
            else:
                logger.debug(f"Verified directory exists: {dir_path}")
        
        # Create default config if it doesn't exist
        config_path = os.path.join(base_dir, 'config.yaml')
        if not os.path.exists(config_path):
            logger.debug("Creating default config.yaml")
            default_config = {
                'cache': {
                    'max_memory_cache_size': 1000,
                    'cache_expiry_days': 1,
                    'update_frequency': '1d',
                    'compression_type': 'parquet'
                },
                'download': {
                    'max_retries': 3,
                    'retry_delay': 5,
                    'batch_size': 100,
                    'timeout': 30
                },
                'validation': {
                    'min_data_points': 50,
                    'max_missing_pct': 0.1,
                    'price_threshold': 0.01
                }
            }
            with open(config_path, 'w') as f:
                yaml.dump(default_config, f)
            logger.debug("Created config.yaml successfully")
        else:
            logger.debug("config.yaml already exists")
        
        return {
            'base_dir': base_dir,
            'data_dir': data_dir,
            'db_dir': db_dir,
            'cache_dir': cache_dir,
            'config_path': config_path
        }
    except Exception as e:
        logger.error(f"Error in setup_directories: {str(e)}")
        raise

# %%
start_date = '2022-01-01'
end_date = '2024-01-01'

symbol = 'AAPL'

hist = yf.download(symbol, 
                    start=start_date, 
                    end=end_date, 
                    progress=False)
        # Check if we have data
print(len(hist))

# %%
def verify_data_availability(symbol: str, start_date: str, end_date: str) -> bool:
    """
    Verifies if a symbol has any data available in the specified date range.
    """
    try:
        hist = yf.download(symbol, 
                          start=start_date, 
                          end=end_date, 
                          progress=False)
        
        return not hist.empty
        
    except Exception as e:
        logger.debug(f"Error verifying {symbol}: {str(e)}")
        return False

def get_combined_symbols(num_sp500: int, num_sec: int, start_date: str, end_date: str, logger) -> Tuple[List[str], List[str]]:
    """
    Gets two lists of symbols that have data: S&P 500 and SEC stocks.
    """
    # Get S&P 500 symbols
    try:
        url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
        tables = pd.read_html(url)
        sp500_symbols = tables[0]['Symbol'].tolist()
        sp500_symbols = [symbol.replace(".", "-") for symbol in sp500_symbols]
        logger.info(f"Retrieved {len(sp500_symbols)} S&P 500 symbols")
    except Exception as e:
        logger.error(f"Error retrieving S&P 500 symbols: {str(e)}")
        sp500_symbols = []

    # Get SEC symbols
    try:
        sec_url = "https://www.sec.gov/files/company_tickers.json"
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
        }
        response = requests.get(sec_url, headers=headers)
        data = response.json()
        sec_symbols = {company['ticker'] for company in data.values()}
        logger.info(f"Retrieved {len(sec_symbols)} SEC symbols")
    except Exception as e:
        logger.error(f"Error retrieving SEC symbols: {str(e)}")
        sec_symbols = set()

    sp500_verified = []
    sec_verified = []
    
    # Verify S&P 500 symbols
    logger.info("Verifying S&P 500 symbols...")
    for symbol in sp500_symbols:
        if len(sp500_verified) >= num_sp500:
            break
        if verify_data_availability(symbol, start_date, end_date):
            sp500_verified.append(symbol)

    # Verify SEC symbols (excluding S&P 500)
    logger.info("Verifying SEC symbols...")
    sp500_set = set(sp500_symbols)
    additional_symbols = [sym for sym in sec_symbols if sym not in sp500_set]
    
    for symbol in additional_symbols:
        if len(sec_verified) >= num_sec:
            break
        if verify_data_availability(symbol, start_date, end_date):
            sec_verified.append(symbol)

    logger.info(f"Found {len(sp500_verified)} S&P 500 symbols and {len(sec_verified)} SEC symbols with data")
    return sp500_verified, sec_verified

# %%
START_DATE = '2022-01-01'
END_DATE = '2024-01-01'

# Get symbols
sp500_symbols, sec_symbols = get_combined_symbols(500, 100, START_DATE, END_DATE, logger)
print(f"Retrieved {len(sp500_symbols)} verified symbols")
print(f"Retrieved {len(sec_symbols)} verified symbols")
# Out:
# 2024-12-27 23:19:26,410 - __main__ - INFO - Retrieved 503 S&P 500 symbols
# 2024-12-27 23:19:26,593 - __main__ - INFO - Retrieved 10038 SEC symbols
# 2024-12-27 23:19:26,594 - __main__ - INFO - Verifying S&P 500 symbols...
# 2024-12-27 23:19:53,492 - yfinance - ERROR -
# 1 Failed download:
# 2024-12-27 23:19:53,492 - yfinance - ERROR - ['GEV']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2022-01-01 -> 2024-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1641013200, endDate = 1704085200")')
# 2024-12-27 23:20:20,478 - yfinance - ERROR -
# 1 Failed download:
# 2024-12-27 23:20:20,481 - yfinance - ERROR - ['SW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2022-01-01 -> 2024-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1641013200, endDate = 1704085200")')
# 2024-12-27 23:20:21,397 - yfinance - ERROR -
# 1 Failed download:
# 2024-12-27 23:20:21,399 - yfinance - ERROR - ['SOLV']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2022-01-01 -> 2024-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1641013200, endDate = 1704085200")')
# 2024-12-27 23:20:31,700 - __main__ - INFO - Verifying SEC symbols...
# 2024-12-27 23:20:32,779 - yfinance - ERROR -
# 1 Failed download:
# 2024-12-27 23:20:32,780 - yfinance - ERROR - ['PACS']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2022-01-01 -> 2024-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1641013200, endDate = 1704085200")')
# 2024-12-27 23:20:33,721 - yfinance - ERROR -
# 1 Failed download:
# 2024-12-27 23:20:33,722 - yfinance - ERROR - ['SPHL']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2022-01-01 -> 2024-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1641013200, endDate = 1704085200")')
# 2024-12-27 23:20:35,833 - yfinance - ERROR -
# 1 Failed download:
# 2024-12-27 23:20:35,834 - yfinance - ERROR - ['EWSB']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2022-01-01 -> 2024-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1641013200, endDate = 1704085200")')
# 2024-12-27 23:20:39,834 - yfinance - ERROR -
# 1 Failed download:
# 2024-12-27 23:20:39,835 - yfinance - ERROR - ['LTM']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2022-01-01 -> 2024-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1641013200, endDate = 1704085200")')
# 2024-12-27 23:20:39,914 - yfinance - ERROR -
# 1 Failed download:
# 2024-12-27 23:20:39,915 - yfinance - ERROR - ['BODYW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2022-01-01 -> 2024-01-01)')
# 2024-12-27 23:20:41,899 - yfinance - ERROR -
# 1 Failed download:
# 2024-12-27 23:20:41,901 - yfinance - ERROR - ['RFACR']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2022-01-01 -> 2024-01-01)')
# 2024-12-27 23:20:44,685 - yfinance - ERROR -
# 1 Failed download:
# 2024-12-27 23:20:44,686 - yfinance - ERROR - ['TRINI']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2022-01-01 -> 2024-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1641013200, endDate = 1704085200")')
# 2024-12-27 23:20:44,762 - yfinance - ERROR -
# 1 Failed download:
# 2024-12-27 23:20:44,763 - yfinance - ERROR - ['RCKTW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2022-01-01 -> 2024-01-01)')
# 2024-12-27 23:20:46,009 - yfinance - ERROR -
# 1 Failed download:
# 2024-12-27 23:20:46,010 - yfinance - ERROR - ['BC-PC']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2022-01-01 -> 2024-01-01)')
# 2024-12-27 23:20:48,091 - yfinance - ERROR -
# 1 Failed download:
# 2024-12-27 23:20:48,092 - yfinance - ERROR - ['RDAC']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2022-01-01 -> 2024-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1641013200, endDate = 1704085200")')
# 2024-12-27 23:20:50,150 - yfinance - ERROR -
# 1 Failed download:
# 2024-12-27 23:20:50,150 - yfinance - ERROR - ['OACC']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2022-01-01 -> 2024-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1641013200, endDate = 1704085200")')
# 2024-12-27 23:20:52,799 - yfinance - ERROR -
# 1 Failed download:
# 2024-12-27 23:20:52,801 - yfinance - ERROR - ['NPWR-WT']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2022-01-01 -> 2024-01-01)')
# 2024-12-27 23:20:53,477 - yfinance - ERROR -
# 1 Failed download:
# 2024-12-27 23:20:53,478 - yfinance - ERROR - ['MARXR']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2022-01-01 -> 2024-01-01)')
# 2024-12-27 23:20:53,986 - __main__ - INFO - Found 500 S&P 500 symbols and 100 SEC symbols with data
# Retrieved 500 verified symbols
# Retrieved 100 verified symbols

# %%
verified_symbols = sp500_symbols + sec_symbols

# Use with your backtest
bt = Backtest(config_path='config/config.yaml', start_date=START_DATE, end_date=END_DATE)
data = bt.fetch_historical_data(verified_symbols)
# Out:
# 2024-12-27 23:24:33,525 - Backtest - INFO - Starting fetch_historical_data for 600 symbols
# 2024-12-27 23:24:33,525 - Backtest - INFO - Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# 2024-12-27 23:24:33,526 - Backtest - INFO - Creating new BacktestDataManager instance
# Loaded configuration from config/config.yaml
# 2024-12-27 23:24:33,536 - Backtest - INFO - Calling data_manager.get_data
#
# === Starting get_data ===
# Input symbols: ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'APO', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BAX', 'BDX', 'BRK-B', 'BBY', 'TECH', 'BIIB', 'BLK', 'BX', 'BK', 'BA', 'BKNG', 'BWA', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF-B', 'BLDR', 'BG', 'BXP', 'CHRW', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'COR', 'CNC', 'CNP', 'CF', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CPAY', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CRWD', 'CCI', 'CSX', 'CMI', 'CVS', 'DHR', 'DRI', 'DVA', 'DAY', 'DECK', 'DE', 'DELL', 'DAL', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DHI', 'DTE', 'DUK', 'DD', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 'EQR', 'ERIE', 'ESS', 'EL', 'EG', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FICO', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FSLR', 'FE', 'FI', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GE', 'GEHC', 'GEN', 'GNRC', 'GD', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GL', 'GDDY', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'DOC', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUBB', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'INCY', 'IR', 'PODD', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JBL', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KVUE', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KKR', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LII', 'LLY', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LULU', 'LYB', 'MTB', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PKG', 'PLTR', 'PANW', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STLD', 'STE', 'SYK', 'SMCI', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TPL', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UBER', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VLTO', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VTRS', 'VICI', 'V', 'VST', 'VMC', 'WRB', 'GWW', 'WAB', 'WBA', 'WMT', 'DIS', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WY', 'WMB', 'WTW', 'WDAY', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZTS', 'PAAS', 'DAR', 'NNI', 'TBI', 'FYBR', 'CTLPP', 'ASO', 'EGF', 'MNYWW', 'CNPWP', 'ALTO', 'ALCO', 'DTGI', 'CBIH', 'CNNE', 'ZEUS', 'TR', 'DMXCF', 'IVDN', 'NTST', 'G', 'ITGR', 'LICY', 'MLGO', 'SATT', 'CAPL', 'BRBL', 'FBK', 'CIO', 'CADCX', 'STGW', 'URG', 'RNST', 'HLX', 'AE', 'MUFG', 'KOSS', 'GWTI', 'HOVVB', 'MCFT', 'WES', 'BUJAU', 'NIU', 'LTBR', 'THG', 'INBS', 'RCAR', 'PAYO', 'HXL', 'PHD', 'WNEB', 'HMY' ...
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
#
# Validating symbols...
#
# === Starting symbol validation ===
# Validating 600 symbols: ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'APO', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BAX', 'BDX', 'BRK-B', 'BBY', 'TECH', 'BIIB', 'BLK', 'BX', 'BK', 'BA', 'BKNG', 'BWA', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF-B', 'BLDR', 'BG', 'BXP', 'CHRW', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'COR', 'CNC', 'CNP', 'CF', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CPAY', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CRWD', 'CCI', 'CSX', 'CMI', 'CVS', 'DHR', 'DRI', 'DVA', 'DAY', 'DECK', 'DE', 'DELL', 'DAL', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DHI', 'DTE', 'DUK', 'DD', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 'EQR', 'ERIE', 'ESS', 'EL', 'EG', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FICO', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FSLR', 'FE', 'FI', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GE', 'GEHC', 'GEN', 'GNRC', 'GD', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GL', 'GDDY', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'DOC', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUBB', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'INCY', 'IR', 'PODD', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JBL', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KVUE', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KKR', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LII', 'LLY', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LULU', 'LYB', 'MTB', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PKG', 'PLTR', 'PANW', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STLD', 'STE', 'SYK', 'SMCI', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TPL', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UBER', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VLTO', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VTRS', 'VICI', 'V', 'VST', 'VMC', 'WRB', 'GWW', 'WAB', 'WBA', 'WMT', 'DIS', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WY', 'WMB', 'WTW', 'WDAY', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZTS', 'PAAS', 'DAR', 'NNI', 'TBI', 'FYBR', 'CTLPP', 'ASO', 'EGF', 'MNYWW', 'CNPWP', 'ALTO', 'ALCO', 'DTGI', 'CBIH', 'CNNE', 'ZEUS', 'TR', 'DMXCF', 'IVDN', 'NTST', 'G', 'ITGR', 'LICY', 'MLGO', 'SATT', 'CAPL', 'BRBL', 'FBK', 'CIO', 'CADCX', 'STGW', 'URG', 'RNST', 'HLX', 'AE', 'MUFG', 'KOSS', 'GWTI', 'HOVVB', 'MCFT', 'WES', 'BUJAU', 'NIU', 'LTBR', 'THG', 'INBS', 'RCAR', 'PAYO', 'HXL', 'PHD', 'WNE ...
# Database query result for MMM: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding MMM to valid symbols - date range acceptable
# Database query result for AOS: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AOS to valid symbols - date range acceptable
# Database query result for ABT: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ABT to valid symbols - date range acceptable
# Database query result for ABBV: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ABBV to valid symbols - date range acceptable
# Database query result for ACN: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ACN to valid symbols - date range acceptable
# Database query result for ADBE: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ADBE to valid symbols - date range acceptable
# Database query result for AMD: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AMD to valid symbols - date range acceptable
# Database query result for AES: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AES to valid symbols - date range acceptable
# Database query result for AFL: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AFL to valid symbols - date range acceptable
# Database query result for A: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding A to valid symbols - date range acceptable
# Database query result for APD: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding APD to valid symbols - date range acceptable
# Database query result for ABNB: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ABNB to valid symbols - date range acceptable
# Database query result for AKAM: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AKAM to valid symbols - date range acceptable
# Database query result for ALB: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ALB to valid symbols - date range acceptable
# Database query result for ARE: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ARE to valid symbols - date range acceptable
# Database query result for ALGN: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ALGN to valid symbols - date range acceptable
# Database query result for ALLE: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ALLE to valid symbols - date range acceptable
# Database query result for LNT: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding LNT to valid symbols - date range acceptable
# Database query result for ALL: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ALL to valid symbols - date range acceptable
# Database query result for GOOGL: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding GOOGL to valid symbols - date range acceptable
# Database query result for GOOG: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding GOOG to valid symbols - date range acceptable
# Database query result for MO: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding MO to valid symbols - date range acceptable
# Database query result for AMZN: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AMZN to valid symbols - date range acceptable
# Database query result for AMCR: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AMCR to valid symbols - date range acceptable
# Database query result for AEE: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AEE to valid symbols - date range acceptable
# Database query result for AEP: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AEP to valid symbols - date range acceptable
# Database query result for AXP: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AXP to valid symbols - date range acceptable
# Database query result for AIG: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AIG to valid symbols - date range acceptable
# Database query result for AMT: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AMT to valid symbols - date range acceptable
# Database query result for AWK: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AWK to valid symbols - date range acceptable
# Database query result for AMP: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AMP to valid symbols - date range acceptable
# Database query result for AME: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AME to valid symbols - date range acceptable
# Database query result for AMGN: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AMGN to valid symbols - date range acceptable
# Database query result for APH: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding APH to valid symbols - date range acceptable
# Database query result for ADI: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ADI to valid symbols - date range acceptable
# Database query result for ANSS: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ANSS to valid symbols - date range acceptable
# Database query result for AON: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AON to valid symbols - date range acceptable
# Database query result for APA: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding APA to valid symbols - date range acceptable
# Database query result for APO: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding APO to valid symbols - date range acceptable
# Database query result for AAPL: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AAPL to valid symbols - date range acceptable
# Database query result for AMAT: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AMAT to valid symbols - date range acceptable
# Database query result for APTV: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding APTV to valid symbols - date range acceptable
# Database query result for ACGL: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ACGL to valid symbols - date range acceptable
# Database query result for ADM: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ADM to valid symbols - date range acceptable
# Database query result for ANET: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ANET to valid symbols - date range acceptable
# Database query result for AJG: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AJG to valid symbols - date range acceptable
# Database query result for AIZ: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AIZ to valid symbols - date range acceptable
# Database query result for T: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding T to valid symbols - date range acceptable
# Database query result for ATO: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ATO to valid symbols - date range acceptable
# Database query result for ADSK: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ADSK to valid symbols - date range acceptable
# Database query result for ADP: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ADP to valid symbols - date range acceptable
# Database query result for AZO: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AZO to valid symbols - date range acceptable
# Database query result for AVB: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AVB to valid symbols - date range acceptable
# Database query result for AVY: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AVY to valid symbols - date range acceptable
# Database query result for AXON: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AXON to valid symbols - date range acceptable
# Database query result for BKR: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BKR to valid symbols - date range acceptable
# Database query result for BALL: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BALL to valid symbols - date range acceptable
# Database query result for BAC: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BAC to valid symbols - date range acceptable
# Database query result for BAX: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BAX to valid symbols - date range acceptable
# Database query result for BDX: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BDX to valid symbols - date range acceptable
# Database query result for BRK-B: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BRK-B to valid symbols - date range acceptable
# Database query result for BBY: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BBY to valid symbols - date range acceptable
# Database query result for TECH: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding TECH to valid symbols - date range acceptable
# Database query result for BIIB: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BIIB to valid symbols - date range acceptable
# Database query result for BLK: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BLK to valid symbols - date range acceptable
# Database query result for BX: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BX to valid symbols - date range acceptable
# Database query result for BK: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BK to valid symbols - date range acceptable
# Database query result for BA: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BA to valid symbols - date range acceptable
# Database query result for BKNG: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BKNG to valid symbols - date range acceptable
# Database query result for BWA: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BWA to valid symbols - date range acceptable
# Database query result for BSX: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BSX to valid symbols - date range acceptable
# Database query result for BMY: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BMY to valid symbols - date range acceptable
# Database query result for AVGO: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding AVGO to valid symbols - date range acceptable
# Database query result for BR: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BR to valid symbols - date range acceptable
# Database query result for BRO: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BRO to valid symbols - date range acceptable
# Database query result for BF-B: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BF-B to valid symbols - date range acceptable
# Database query result for BLDR: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BLDR to valid symbols - date range acceptable
# Database query result for BG: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BG to valid symbols - date range acceptable
# Database query result for BXP: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BXP to valid symbols - date range acceptable
# Database query result for CHRW: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CHRW to valid symbols - date range acceptable
# Database query result for CDNS: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CDNS to valid symbols - date range acceptable
# Database query result for CZR: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CZR to valid symbols - date range acceptable
# Database query result for CPT: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CPT to valid symbols - date range acceptable
# Database query result for CPB: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CPB to valid symbols - date range acceptable
# Database query result for COF: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding COF to valid symbols - date range acceptable
# Database query result for CAH: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CAH to valid symbols - date range acceptable
# Database query result for KMX: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding KMX to valid symbols - date range acceptable
# Database query result for CCL: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CCL to valid symbols - date range acceptable
# Database query result for CARR: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CARR to valid symbols - date range acceptable
# Database query result for CAT: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CAT to valid symbols - date range acceptable
# Database query result for CBOE: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CBOE to valid symbols - date range acceptable
# Database query result for CBRE: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CBRE to valid symbols - date range acceptable
# Database query result for CDW: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CDW to valid symbols - date range acceptable
# Database query result for CE: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CE to valid symbols - date range acceptable
# Database query result for COR: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding COR to valid symbols - date range acceptable
# Database query result for CNC: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CNC to valid symbols - date range acceptable
# Database query result for CNP: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CNP to valid symbols - date range acceptable
# Database query result for CF: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CF to valid symbols - date range acceptable
# Database query result for CRL: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CRL to valid symbols - date range acceptable
# Database query result for SCHW: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding SCHW to valid symbols - date range acceptable
# Database query result for CHTR: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CHTR to valid symbols - date range acceptable
# Database query result for CVX: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CVX to valid symbols - date range acceptable
# Database query result for CMG: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CMG to valid symbols - date range acceptable
# Database query result for CB: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CB to valid symbols - date range acceptable
# Database query result for CHD: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CHD to valid symbols - date range acceptable
# Database query result for CI: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CI to valid symbols - date range acceptable
# Database query result for CINF: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CINF to valid symbols - date range acceptable
# Database query result for CTAS: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CTAS to valid symbols - date range acceptable
# Database query result for CSCO: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CSCO to valid symbols - date range acceptable
# Database query result for C: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding C to valid symbols - date range acceptable
# Database query result for CFG: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CFG to valid symbols - date range acceptable
# Database query result for CLX: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CLX to valid symbols - date range acceptable
# Database query result for CME: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CME to valid symbols - date range acceptable
# Database query result for CMS: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CMS to valid symbols - date range acceptable
# Database query result for KO: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding KO to valid symbols - date range acceptable
# Database query result for CTSH: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CTSH to valid symbols - date range acceptable
# Database query result for CL: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CL to valid symbols - date range acceptable
# Database query result for CMCSA: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CMCSA to valid symbols - date range acceptable
# Database query result for CAG: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CAG to valid symbols - date range acceptable
# Database query result for COP: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding COP to valid symbols - date range acceptable
# Database query result for ED: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ED to valid symbols - date range acceptable
# Database query result for STZ: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding STZ to valid symbols - date range acceptable
# Database query result for CEG: (1, '2022-01-19', '2023-12-29')
# Date range in DB: 2022-01-19 to 2023-12-29
# Adding CEG to valid symbols - date range acceptable
# Database query result for COO: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding COO to valid symbols - date range acceptable
# Database query result for CPRT: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CPRT to valid symbols - date range acceptable
# Database query result for GLW: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding GLW to valid symbols - date range acceptable
# Database query result for CPAY: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CPAY to valid symbols - date range acceptable
# Database query result for CTVA: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CTVA to valid symbols - date range acceptable
# Database query result for CSGP: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CSGP to valid symbols - date range acceptable
# Database query result for COST: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding COST to valid symbols - date range acceptable
# Database query result for CTRA: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CTRA to valid symbols - date range acceptable
# Database query result for CRWD: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CRWD to valid symbols - date range acceptable
# Database query result for CCI: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CCI to valid symbols - date range acceptable
# Database query result for CSX: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CSX to valid symbols - date range acceptable
# Database query result for CMI: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CMI to valid symbols - date range acceptable
# Database query result for CVS: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding CVS to valid symbols - date range acceptable
# Database query result for DHR: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DHR to valid symbols - date range acceptable
# Database query result for DRI: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DRI to valid symbols - date range acceptable
# Database query result for DVA: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DVA to valid symbols - date range acceptable
# Database query result for DAY: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DAY to valid symbols - date range acceptable
# Database query result for DECK: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DECK to valid symbols - date range acceptable
# Database query result for DE: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DE to valid symbols - date range acceptable
# Database query result for DELL: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DELL to valid symbols - date range acceptable
# Database query result for DAL: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DAL to valid symbols - date range acceptable
# Database query result for DVN: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DVN to valid symbols - date range acceptable
# Database query result for DXCM: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DXCM to valid symbols - date range acceptable
# Database query result for FANG: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding FANG to valid symbols - date range acceptable
# Database query result for DLR: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DLR to valid symbols - date range acceptable
# Database query result for DFS: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DFS to valid symbols - date range acceptable
# Database query result for DG: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DG to valid symbols - date range acceptable
# Database query result for DLTR: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DLTR to valid symbols - date range acceptable
# Database query result for D: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding D to valid symbols - date range acceptable
# Database query result for DPZ: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DPZ to valid symbols - date range acceptable
# Database query result for DOV: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DOV to valid symbols - date range acceptable
# Database query result for DOW: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DOW to valid symbols - date range acceptable
# Database query result for DHI: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DHI to valid symbols - date range acceptable
# Database query result for DTE: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DTE to valid symbols - date range acceptable
# Database query result for DUK: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DUK to valid symbols - date range acceptable
# Database query result for DD: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DD to valid symbols - date range acceptable
# Database query result for EMN: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding EMN to valid symbols - date range acceptable
# Database query result for ETN: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ETN to valid symbols - date range acceptable
# Database query result for EBAY: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding EBAY to valid symbols - date range acceptable
# Database query result for ECL: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ECL to valid symbols - date range acceptable
# Database query result for EIX: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding EIX to valid symbols - date range acceptable
# Database query result for EW: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding EW to valid symbols - date range acceptable
# Database query result for EA: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding EA to valid symbols - date range acceptable
# Database query result for ELV: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ELV to valid symbols - date range acceptable
# Database query result for EMR: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding EMR to valid symbols - date range acceptable
# Database query result for ENPH: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ENPH to valid symbols - date range acceptable
# Database query result for ETR: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ETR to valid symbols - date range acceptable
# Database query result for EOG: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding EOG to valid symbols - date range acceptable
# Database query result for EPAM: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding EPAM to valid symbols - date range acceptable
# Database query result for EQT: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding EQT to valid symbols - date range acceptable
# Database query result for EFX: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding EFX to valid symbols - date range acceptable
# Database query result for EQIX: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding EQIX to valid symbols - date range acceptable
# Database query result for EQR: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding EQR to valid symbols - date range acceptable
# Database query result for ERIE: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ERIE to valid symbols - date range acceptable
# Database query result for ESS: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ESS to valid symbols - date range acceptable
# Database query result for EL: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding EL to valid symbols - date range acceptable
# Database query result for EG: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding EG to valid symbols - date range acceptable
# Database query result for EVRG: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding EVRG to valid symbols - date range acceptable
# Database query result for ES: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ES to valid symbols - date range acceptable
# Database query result for EXC: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding EXC to valid symbols - date range acceptable
# Database query result for EXPE: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding EXPE to valid symbols - date range acceptable
# Database query result for EXPD: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding EXPD to valid symbols - date range acceptable
# Database query result for EXR: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding EXR to valid symbols - date range acceptable
# Database query result for XOM: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding XOM to valid symbols - date range acceptable
# Database query result for FFIV: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding FFIV to valid symbols - date range acceptable
# Database query result for FDS: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding FDS to valid symbols - date range acceptable
# Database query result for FICO: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding FICO to valid symbols - date range acceptable
# Database query result for FAST: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding FAST to valid symbols - date range acceptable
# Database query result for FRT: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding FRT to valid symbols - date range acceptable
# Database query result for FDX: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding FDX to valid symbols - date range acceptable
# Database query result for FIS: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding FIS to valid symbols - date range acceptable
# Database query result for FITB: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding FITB to valid symbols - date range acceptable
# Database query result for FSLR: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding FSLR to valid symbols - date range acceptable
# Database query result for FE: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding FE to valid symbols - date range acceptable
# Database query result for FI: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding FI to valid symbols - date range acceptable
# Database query result for FMC: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding FMC to valid symbols - date range acceptable
# Database query result for F: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding F to valid symbols - date range acceptable
# Database query result for FTNT: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding FTNT to valid symbols - date range acceptable
# Database query result for FTV: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding FTV to valid symbols - date range acceptable
# Database query result for FOXA: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding FOXA to valid symbols - date range acceptable
# Database query result for FOX: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding FOX to valid symbols - date range acceptable
# Database query result for BEN: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding BEN to valid symbols - date range acceptable
# Database query result for FCX: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding FCX to valid symbols - date range acceptable
# Database query result for GRMN: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding GRMN to valid symbols - date range acceptable
# Database query result for IT: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding IT to valid symbols - date range acceptable
# Database query result for GE: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding GE to valid symbols - date range acceptable
# Database query result for GEHC: (1, '2022-12-15', '2023-12-29')
# Date range in DB: 2022-12-15 to 2023-12-29
# Adding GEHC to valid symbols - date range acceptable
# Database query result for GEN: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding GEN to valid symbols - date range acceptable
# Database query result for GNRC: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding GNRC to valid symbols - date range acceptable
# Database query result for GD: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding GD to valid symbols - date range acceptable
# Database query result for GIS: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding GIS to valid symbols - date range acceptable
# Database query result for GM: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding GM to valid symbols - date range acceptable
# Database query result for GPC: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding GPC to valid symbols - date range acceptable
# Database query result for GILD: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding GILD to valid symbols - date range acceptable
# Database query result for GPN: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding GPN to valid symbols - date range acceptable
# Database query result for GL: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding GL to valid symbols - date range acceptable
# Database query result for GDDY: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding GDDY to valid symbols - date range acceptable
# Database query result for GS: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding GS to valid symbols - date range acceptable
# Database query result for HAL: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding HAL to valid symbols - date range acceptable
# Database query result for HIG: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding HIG to valid symbols - date range acceptable
# Database query result for HAS: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding HAS to valid symbols - date range acceptable
# Database query result for HCA: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding HCA to valid symbols - date range acceptable
# Database query result for DOC: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding DOC to valid symbols - date range acceptable
# Database query result for HSIC: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding HSIC to valid symbols - date range acceptable
# Database query result for HSY: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding HSY to valid symbols - date range acceptable
# Database query result for HES: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding HES to valid symbols - date range acceptable
# Database query result for HPE: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding HPE to valid symbols - date range acceptable
# Database query result for HLT: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding HLT to valid symbols - date range acceptable
# Database query result for HOLX: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding HOLX to valid symbols - date range acceptable
# Database query result for HD: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding HD to valid symbols - date range acceptable
# Database query result for HON: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding HON to valid symbols - date range acceptable
# Database query result for HRL: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding HRL to valid symbols - date range acceptable
# Database query result for HST: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding HST to valid symbols - date range acceptable
# Database query result for HWM: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding HWM to valid symbols - date range acceptable
# Database query result for HPQ: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding HPQ to valid symbols - date range acceptable
# Database query result for HUBB: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding HUBB to valid symbols - date range acceptable
# Database query result for HUM: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding HUM to valid symbols - date range acceptable
# Database query result for HBAN: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding HBAN to valid symbols - date range acceptable
# Database query result for HII: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding HII to valid symbols - date range acceptable
# Database query result for IBM: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding IBM to valid symbols - date range acceptable
# Database query result for IEX: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding IEX to valid symbols - date range acceptable
# Database query result for IDXX: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding IDXX to valid symbols - date range acceptable
# Database query result for ITW: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding ITW to valid symbols - date range acceptable
# Database query result for INCY: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding INCY to valid symbols - date range acceptable
# Database query result for IR: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding IR to valid symbols - date range acceptable
# Database query result for PODD: (1, '2022-01-03', '2023-12-29')
# Date range in DB: 2022-01-03 to 2023-12-29
# Adding PODD to valid symbols - date range acceptable
# ...
# No data returned for NMKBP
# Downloaded 0 rows of data for COGT
# No data returned for COGT
#
# === Downloading data for FSUN ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for FSUN
#
# Processing result for symbol: COGT
# No data returned for COGT
# 2024-12-27 23:26:07,339 - yfinance - ERROR - $WSR: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for WSR
# No data returned for WSR
# 2024-12-27 23:26:07,339 - yfinance - ERROR - $ACR-PC: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
#
# === Downloading data for RDFN ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for RDFN
#
# Processing result for symbol: WSR
# No data returned for WSR
# Downloaded 0 rows of data for ACR-PC
# No data returned for ACR-PC
#
# === Downloading data for SPCB ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for SPCB
# 2024-12-27 23:26:07,339 - yfinance - ERROR - $CMGO: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
#
# Processing result for symbol: ACR-PC
# No data returned for ACR-PC
# Downloaded 0 rows of data for CMGO
# No data returned for CMGO
#
# === Downloading data for ALX ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for ALX
# 2024-12-27 23:26:07,340 - yfinance - ERROR - $FSUN: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
#
# Processing result for symbol: CMGO
# No data returned for CMGO
# Downloaded 0 rows of data for FSUN
# No data returned for FSUN
#
# === Downloading data for BIP-PB ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for BIP-PB
# 2024-12-27 23:26:07,341 - yfinance - ERROR - $FTHY: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
#
# Processing result for symbol: FSUN
# No data returned for FSUN
# Downloaded 0 rows of data for FTHY
# No data returned for FTHY
#
# === Downloading data for ZYME ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for ZYME
#
# Processing result for symbol: FTHY
# No data returned for FTHY
# 2024-12-27 23:26:07,936 - yfinance - ERROR - $RDFN: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for RDFN
# No data returned for RDFN
#
# === Downloading data for ALAR ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for ALAR
# 2024-12-27 23:26:07,936 - yfinance - ERROR - $ZYME: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
#
# Processing result for symbol: RDFN
# No data returned for RDFN
# Downloaded 0 rows of data for ZYME
# No data returned for ZYME
#
# === Downloading data for BSY ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for BSY
# 2024-12-27 23:26:07,938 - yfinance - ERROR - $BIP-PB: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
#
# Processing result for symbol: ZYME
# No data returned for ZYME
# Downloaded 0 rows of data for BIP-PB
# No data returned for BIP-PB
#
# === Downloading data for GLSTU ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for GLSTU
# 2024-12-27 23:26:07,939 - yfinance - ERROR - $ALX: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
#
# Processing result for symbol: BIP-PBDownloaded 0 rows of data for ALX
# No data returned for ALX
#
# === Downloading data for PCG-PD ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for PCG-PD
#
# No data returned for BIP-PB
#
# Processing result for symbol: ALX
# No data returned for ALX
# 2024-12-27 23:26:07,941 - yfinance - ERROR - $SPCB: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for SPCB
# No data returned for SPCB
#
# === Downloading data for STAA ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for STAA
#
# Processing result for symbol: SPCB
# No data returned for SPCB
# 2024-12-27 23:26:08,499 - yfinance - ERROR - $BSY: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for BSY
# No data returned for BSY
# 2024-12-27 23:26:08,499 - yfinance - ERROR - $PCG-PD: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
#
# Processing result for symbol: BSY
# No data returned for BSY
#
# === Downloading data for SSUNF ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for SSUNF
# Downloaded 0 rows of data for PCG-PD
# No data returned for PCG-PD
# 2024-12-27 23:26:08,501 - yfinance - ERROR - $GLSTU: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
#
# === Downloading data for XDSL ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for XDSL
#
# Processing result for symbol: PCG-PD
# No data returned for PCG-PD
# Downloaded 0 rows of data for GLSTU
# No data returned for GLSTU
#
# === Downloading data for BAFBF ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for BAFBF
# 2024-12-27 23:26:08,502 - yfinance - ERROR - $STAA: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
#
# Processing result for symbol: GLSTU
# No data returned for GLSTU
# Downloaded 0 rows of data for STAA
# No data returned for STAA
#
# === Downloading data for SALM ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for SALM
# 2024-12-27 23:26:08,502 - yfinance - ERROR - $ALAR: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for ALAR
# No data returned for ALAR
#
# === Downloading data for COLD ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for COLD
#
# Processing result for symbol: STAA
# No data returned for STAA
#
# Processing result for symbol: ALAR
# No data returned for ALAR
# 2024-12-27 23:26:09,095 - yfinance - ERROR - $COLD: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for COLD
# No data returned for COLD
#
# Processing result for symbol: COLD
# No data returned for COLD
#
# === Downloading data for CHNEY ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for CHNEY
# 2024-12-27 23:26:09,095 - yfinance - ERROR - $SALM: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for SALM
# No data returned for SALM
#
# === Downloading data for NGVC ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for NGVC
# 2024-12-27 23:26:09,095 - yfinance - ERROR - $BAFBF: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
#
# Processing result for symbol: SALM
# No data returned for SALM
# Downloaded 0 rows of data for BAFBF
# No data returned for BAFBF
#
# === Downloading data for KANT ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for KANT
# 2024-12-27 23:26:09,096 - yfinance - ERROR - $XDSL: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
#
# Processing result for symbol: BAFBF
# No data returned for BAFBF
# Downloaded 0 rows of data for XDSL
# No data returned for XDSL
#
# === Downloading data for BRK-A ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for BRK-A
# 2024-12-27 23:26:09,096 - yfinance - ERROR - $SSUNF: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
#
# Processing result for symbol: XDSL
# No data returned for XDSL
# Downloaded 0 rows of data for SSUNF
# No data returned for SSUNF
#
# === Downloading data for EB ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for EB
#
# Processing result for symbol: SSUNF
# No data returned for SSUNF
# 2024-12-27 23:26:09,943 - yfinance - ERROR - $NGVC: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for NGVC
# No data returned for NGVC
# 2024-12-27 23:26:09,944 - yfinance - ERROR - $KANT: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
#
# === Downloading data for RSVRW ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for RSVRW
#
# Processing result for symbol: NGVC
# No data returned for NGVC
# Downloaded 0 rows of data for KANT
# No data returned for KANT
#
# === Downloading data for NEWP ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for NEWP
#
# Processing result for symbol: KANT
# No data returned for KANT
# 2024-12-27 23:26:09,945 - yfinance - ERROR - $BRK-A: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for BRK-A
# No data returned for BRK-A
#
# === Downloading data for MARXU ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for MARXU
# 2024-12-27 23:26:09,945 - yfinance - ERROR - $CHNEY: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
#
# Processing result for symbol: BRK-A
# No data returned for BRK-A
# Downloaded 0 rows of data for CHNEY
# No data returned for CHNEY
#
# === Downloading data for CVI ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for CVI
# 2024-12-27 23:26:09,946 - yfinance - ERROR - $EB: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
#
# Processing result for symbol: CHNEY
# No data returned for CHNEY
# Downloaded 0 rows of data for EB
# No data returned for EB
#
# === Downloading data for ANDE ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for ANDE
#
# Processing result for symbol: EB
# No data returned for EB
# 2024-12-27 23:26:10,580 - yfinance - ERROR - $RSVRW: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for RSVRW
# No data returned for RSVRW
#
# === Downloading data for ODD ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for ODD
#
# Processing result for symbol: RSVRW
# No data returned for RSVRW
# 2024-12-27 23:26:10,585 - yfinance - ERROR - $NEWP: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for NEWP
# No data returned for NEWP
#
# === Downloading data for NCRRP ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for NCRRP
#
# Processing result for symbol: NEWP
# No data returned for NEWP
# 2024-12-27 23:26:10,587 - yfinance - ERROR - $CVI: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for CVI
# No data returned for CVI
#
# === Downloading data for SHCO ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for SHCO
#
# Processing result for symbol: CVI
# No data returned for CVI
# 2024-12-27 23:26:10,590 - yfinance - ERROR - $MARXU: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for MARXU
# No data returned for MARXU
#
# === Downloading data for CSTAF ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for CSTAF
# 2024-12-27 23:26:10,590 - yfinance - ERROR - $ANDE: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
#
# Processing result for symbol: MARXU
# No data returned for MARXU
# Downloaded 0 rows of data for ANDE
# No data returned for ANDE
#
# === Downloading data for ALTS ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for ALTS
#
# Processing result for symbol: ANDE
# No data returned for ANDE
# 2024-12-27 23:26:11,185 - yfinance - ERROR - $ODD: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for ODD
# No data returned for ODD
#
# Processing result for symbol: ODD
# No data returned for ODD
#
# === Downloading data for BWXT ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for BWXT
# 2024-12-27 23:26:11,185 - yfinance - ERROR - $SHCO: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for SHCO
# No data returned for SHCO
#
# === Downloading data for GTEC ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for GTEC
# 2024-12-27 23:26:11,186 - yfinance - ERROR - $NCRRP: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
#
# Processing result for symbol: SHCO
# No data returned for SHCO
# Downloaded 0 rows of data for NCRRP
# No data returned for NCRRP
#
# === Downloading data for POAI ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for POAI
#
# Processing result for symbol: NCRRP
# No data returned for NCRRP
# 2024-12-27 23:26:11,189 - yfinance - ERROR - $ALTS: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for ALTS
# No data returned for ALTS
#
# === Downloading data for BTDG ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for BTDG
#
# Processing result for symbol: ALTS
# No data returned for ALTS
# 2024-12-27 23:26:11,232 - yfinance - ERROR - $CSTAF: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for CSTAF
# No data returned for CSTAF
#
# === Downloading data for SSSSL ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for SSSSL
#
# Processing result for symbol: CSTAF
# No data returned for CSTAF
# 2024-12-27 23:26:11,802 - yfinance - ERROR - $POAI: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for POAI
# No data returned for POAI
#
# === Downloading data for RMTI ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for RMTI
# 2024-12-27 23:26:11,802 - yfinance - ERROR - $GTEC: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
#
# Processing result for symbol: POAI
# No data returned for POAI
# Downloaded 0 rows of data for GTEC
# No data returned for GTEC
#
# === Downloading data for USM ===
# Date range: 2022-01-01 00:00:00 to 2024-01-01 00:00:00
# Download attempt 1 for USM
# 2024-12-27 23:26:11,802 - yfinance - ERROR - $BWXT: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
#
# Processing result for symbol: GTECDownloaded 0 rows of data for BWXT
# No data returned for BWXT
#
# No data returned for GTEC
#
# Processing result for symbol: BWXT
# No data returned for BWXT
# 2024-12-27 23:26:11,803 - yfinance - ERROR - $BTDG: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for BTDG
# No data returned for BTDG
#
# Processing result for symbol: BTDG
# No data returned for BTDG
# 2024-12-27 23:26:12,613 - yfinance - ERROR - $SSSSL: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for SSSSL
# No data returned for SSSSL
#
# Processing result for symbol: SSSSL
# No data returned for SSSSL
# 2024-12-27 23:26:13,149 - yfinance - ERROR - $USM: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for USM
# No data returned for USM
#
# Processing result for symbol: USM
# No data returned for USM
# 2024-12-27 23:26:13,149 - yfinance - ERROR - $RMTI: possibly delisted; no price data found  (1d 2022-01-01 00:00:00 -> 2024-01-01 00:00:00)
# Downloaded 0 rows of data for RMTI
# No data returned for RMTI
#
# Processing result for symbol: RMTI
# No data returned for RMTI
#
# === Completed get_data ===
# Successfully retrieved data for 0 symbols: []
# 2024-12-27 23:26:13,152 - Backtest - INFO - Retrieved data for 0 symbols after filtering
# 2024-12-27 23:26:13,152 - Backtest - WARNING - No data remained after filtering

# %%
def analyze_symbol_data(data_dict):
    """
    Analyze a dictionary containing symbols as keys and DataFrames as values.
    
    Args:
        data_dict (dict): A dictionary where keys are symbol strings and values are DataFrames.
    
    Returns:
        None
    """
    if not isinstance(data_dict, dict):
        print("The input is not a dictionary.")
        return
    
    print(f"Total symbols: {len(data_dict)}\n")
    
    for symbol, df in data_dict.items():
        print(f"Symbol: {symbol}")
        if isinstance(df, pd.DataFrame):
            print(f"  Shape: {df.shape}")
            print(f"  Columns: {list(df.columns)}")
            print(f"  Data Types:\n{df.dtypes}")
            print(f"  Memory Usage: {df.memory_usage(deep=True).sum()} bytes")
            print(f"  First 5 rows:\n{df.head()}\n")
        else:
            print(f"  Warning: Value is not a DataFrame (type: {type(df)})\n")
            
# Example usage
# Assuming `symbol_data` is your dictionary
analyze_symbol_data(data)

# %%
# Check if VLTO is in the data
if 'VLTO' in data:
    print("VLTO is still in the data!")
    print(f"VLTO data length: {len(data['VLTO'])}")
else:
    print("VLTO was successfully filtered out")
# Out:
# VLTO was successfully filtered out

# %%
from LSTMManager import LSTMManager

# test_symbols = ['AAPL', 'GOOGL', 'MSFT', 'AMZN', 'META']
# historical_data = bt.fetch_historical_data(test_symbols)

model = LSTMManager()
model.train(data)

# %%
model.optimize_hyperparameters(historical_data)
